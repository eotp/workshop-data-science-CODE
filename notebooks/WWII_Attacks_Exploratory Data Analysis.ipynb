# %% [markdown]
# # Applied Data Analysis I - Exploratory Analysis

# %% [markdown]
# **Import statements**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# **Global settings**

# %%
#pd.options.display.max_rows = 999
#pd.options.display.max_columns = 70
#pd.set_option('display.max_colwidth', -1)
plt.rcParams["figure.figsize"] = [15,6]
#plt.rcParams["ytick.labelsize"] = 14
#plt.rcParams["xtick.labelsize"] = 14

# %% [markdown]
# ## Load data set

# %%
PATH = "../datasets/operations/"
df_raw = pd.read_csv(PATH + "operations.csv", low_memory=False, index_col=0)
df_raw
# Out:
#            Mission Date Theater of Operations        Country Air Force  \
# Mission ID
# 1             8/15/1943                   MTO            USA     12 AF
# 2             8/15/1943                   PTO            USA      5 AF
# 3             8/15/1943                   MTO            USA     12 AF
# 4             8/15/1943                   MTO            USA     12 AF
# 5             8/15/1943                   PTO            USA      5 AF
# 6             8/15/1943                   PTO            USA      5 AF
# 7             8/15/1943                   PTO            USA      5 AF
# 8             8/15/1943                   PTO            USA      5 AF
# 9             8/15/1943                   MTO            USA     12 AF
# 10            8/15/1943                   MTO            USA     12 AF
# 11            8/15/1943                   CBI            USA     10 AF
# 12            8/15/1943                   ETO  GREAT BRITAIN       RAF
# 13            8/15/1943                   ETO  GREAT BRITAIN       RAF
# 14            8/15/1943                   ETO            NaN       NaN
# 15            8/15/1943                   ETO            NaN       NaN
# 16            8/15/1943                   ETO            NaN       NaN
# 17            8/15/1943                   ETO            NaN       NaN
# 18            8/15/1943                   ETO            NaN       NaN
# 19            8/15/1943                   ETO            NaN       NaN
# 20            8/15/1943                   ETO            NaN       NaN
# 21            8/15/1943                   ETO            NaN       NaN
# 22            8/15/1943                   ETO            NaN       NaN
# 23            8/15/1943                   ETO            NaN       NaN
# 24            8/15/1943                   ETO            NaN       NaN
# 25            8/15/1943                   ETO            NaN       NaN
# 26            8/15/1943                   ETO            NaN       NaN
# 27            8/15/1943                   ETO            NaN       NaN
# 28            8/15/1943                   ETO            NaN       NaN
# 29            8/15/1943                   ETO            NaN       NaN
# 30            8/15/1943                   ETO            NaN       NaN
# ...                 ...                   ...            ...       ...
# 178713        2/16/1945                   CBI            USA     10 AF
# 178714        2/16/1945                   CBI            USA     10 AF
# 178715        2/16/1945                   CBI            USA     10 AF
# 178716        2/16/1945                   CBI            USA     10 AF
# 178717        2/16/1945                   CBI            USA     10 AF
# 178718        2/16/1945                   CBI            USA     10 AF
# 178719        2/16/1945                   PTO            USA      5 AF
# 178720        2/16/1945                   PTO            USA     20 AF
# 178721        2/16/1945                   CBI            USA     10 AF
# 178722        2/16/1945                   PTO            USA     13 AF
# 178723        2/16/1945                   CBI            USA     10 AF
# 178724        2/16/1945                   CBI            USA     10 AF
# 178725        2/16/1945                   CBI            USA     10 AF
# 178726        2/16/1945                   CBI            USA     10 AF
# 178727        2/16/1945                   CBI            USA     10 AF
# 178728        2/16/1945                   CBI            USA     10 AF
# 178729        2/16/1945                   CBI            USA     10 AF
# 178730        2/16/1945                   CBI            USA     10 AF
# 178731        2/16/1945                   CBI            USA     10 AF
# 178732        2/16/1945                   CBI            USA     10 AF
# 178733        2/16/1945                   CBI            USA     10 AF
# 178734        2/16/1945                   CBI            USA     10 AF
# 178735        2/16/1945                   CBI            USA     10 AF
# 178736        2/16/1945                   CBI            USA     10 AF
# 178737        2/16/1945                   CBI            USA     10 AF
# 178738        2/16/1945                   CBI            USA     10 AF
# 178739        2/16/1945                   CBI            USA     10 AF
# 178740        2/16/1945                   CBI            USA     10 AF
# 178741        2/16/1945                   PTO    NEW ZEALAND     RNZAF
# 178742        2/16/1945                   CBI            USA     10 AF
#
#                           Unit ID Aircraft Series Callsign Mission Type  \
# Mission ID
# 1                   27 FBG/86 FBG             A36      NaN          NaN
# 2                          400 BS             B24      NaN            1
# 3                   27 FBG/86 FBG             A36      NaN          NaN
# 4                   27 FBG/86 FBG             A36      NaN          NaN
# 5                          321 BS             B24      NaN            1
# 6                          319 BS             B24      NaN            1
# 7                          400 BS             B24      NaN           12
# 8                           65 BS             B17      NaN            1
# 9                   27 FBG/86 FBG             A36      NaN          NaN
# 10                  27 FBG/86 FBG             A36      NaN          NaN
# 11                         436 BS             B24      NaN            2
# 12                            NaN             LGT      NaN          NaN
# 13                            NaN             LGT      NaN          NaN
# 14                            NaN             B17      NaN          NaN
# 15                            NaN             B17      NaN          NaN
# 16                            NaN             B17      NaN          NaN
# 17                            NaN             B17      NaN          NaN
# 18                            NaN             B17      NaN          NaN
# 19                            NaN             B17      NaN          NaN
# 20                            NaN             B17      NaN          NaN
# 21                            NaN             B17      NaN          NaN
# 22                            NaN             B17      NaN          NaN
# 23                            NaN             B17      NaN          NaN
# 24                            NaN             B17      NaN          NaN
# 25                            NaN             B17      NaN          NaN
# 26                            NaN             B17      NaN          NaN
# 27                            NaN             B17      NaN          NaN
# 28                            NaN             B17      NaN          NaN
# 29                            NaN            GB17      NaN          NaN
# 30                            NaN             B17      NaN          NaN
# ...                           ...             ...      ...          ...
# 178713                      89 FS             P47      NaN           10
# 178714                      89 FS             P47      NaN           10
# 178715                      60 FS             P47      NaN           10
# 178716                      60 FS             P47      NaN           10
# 178717                      89 FS             P47      NaN           10
# 178718                      89 FS             P47      NaN           10
# 178719                     499 BS             B25      NaN           10
# 178720                        888             B29      NaN           99
# 178721                     459 FS             P38      NaN           10
# 178722                     868 BS             B24      NaN            1
# 178723                      58 FS             P38      NaN           10
# 178724                      58 FS             P38      NaN           10
# 178725                      58 FS             P38      NaN           10
# 178726                       1 FS             P51      NaN           10
# 178727                      89 FS             P47      NaN           10
# 178728                      89 FS             P47      NaN           10
# 178729                       1 BG             B25      NaN            1
# 178730                       1 BG             B25      NaN            1
# 178731                      88 FS             P47      NaN           10
# 178732                      90 FS             P47      NaN           10
# 178733                      90 FS             P47      NaN           10
# 178734                      90 FS             P47      NaN           10
# 178735                      90 FS             P47      NaN           10
# 178736                      90 FS             P47      NaN           10
# 178737                      90 FS             P47      NaN           10
# 178738                      89 FS             P47      NaN           10
# 178739                      90 FS             P47      NaN           10
# 178740                      90 FS             P47      NaN           10
# 178741      NO. 22 SQUADRON RNZAF             F4U      NaN          NaN
# 178742                      59 FS             P47      NaN           10
#
#                     Takeoff Base Takeoff Location    ...      \
# Mission ID                                           ...
# 1           PONTE OLIVO AIRFIELD           SICILY    ...
# 2                            NaN              NaN    ...
# 3           PONTE OLIVO AIRFIELD           SICILY    ...
# 4           PONTE OLIVO AIRFIELD           SICILY    ...
# 5                            NaN              NaN    ...
# 6                            NaN              NaN    ...
# 7                            NaN              NaN    ...
# 8                            NaN              NaN    ...
# 9           PONTE OLIVO AIRFIELD           SICILY    ...
# 10          PONTE OLIVO AIRFIELD           SICILY    ...
# 11                           NaN              NaN    ...
# 12                           NaN              NaN    ...
# 13                           NaN              NaN    ...
# 14                           NaN              NaN    ...
# 15                           NaN              NaN    ...
# 16                           NaN              NaN    ...
# 17                           NaN              NaN    ...
# 18                           NaN              NaN    ...
# 19                           NaN              NaN    ...
# 20                           NaN              NaN    ...
# 21                           NaN              NaN    ...
# 22                           NaN              NaN    ...
# 23                           NaN              NaN    ...
# 24                           NaN              NaN    ...
# 25                           NaN              NaN    ...
# 26                           NaN              NaN    ...
# 27                           NaN              NaN    ...
# 28                           NaN              NaN    ...
# 29                           NaN              NaN    ...
# 30                           NaN              NaN    ...
# ...                          ...              ...    ...
# 178713                       NaN              NaN    ...
# 178714                       NaN              NaN    ...
# 178715                       NaN              NaN    ...
# 178716                       NaN              NaN    ...
# 178717                       NaN              NaN    ...
# 178718                       NaN              NaN    ...
# 178719                       NaN              NaN    ...
# 178720                       NaN              NaN    ...
# 178721                       NaN              NaN    ...
# 178722                       NaN              NaN    ...
# 178723                       NaN              NaN    ...
# 178724                       NaN              NaN    ...
# 178725                       NaN              NaN    ...
# 178726                       NaN              NaN    ...
# 178727                       NaN              NaN    ...
# 178728                       NaN              NaN    ...
# 178729                       NaN              NaN    ...
# 178730                       NaN              NaN    ...
# 178731                       NaN              NaN    ...
# 178732                       NaN              NaN    ...
# 178733                       NaN              NaN    ...
# 178734                       NaN              NaN    ...
# 178735                       NaN              NaN    ...
# 178736                       NaN              NaN    ...
# 178737                       NaN              NaN    ...
# 178738                       NaN              NaN    ...
# 178739                       NaN              NaN    ...
# 178740                       NaN              NaN    ...
# 178741                       NaN              NaN    ...
# 178742                       NaN              NaN    ...
#
#            Incendiary Devices Weight (Tons)  Fragmentation Devices  \
# Mission ID
# 1                                       NaN                    NaN
# 2                                       NaN                    NaN
# 3                                       NaN                    NaN
# 4                                       NaN                    NaN
# 5                                       NaN                    NaN
# 6                                       NaN                    NaN
# 7                                       NaN                    NaN
# 8                                       NaN                    NaN
# 9                                       NaN                    NaN
# 10                                      NaN                    NaN
# 11                                      NaN                    NaN
# 12                                      NaN                    NaN
# 13                                      NaN                    NaN
# 14                                      NaN                    NaN
# 15                                      NaN                    NaN
# 16                                      NaN                    NaN
# 17                                      NaN                    NaN
# 18                                      NaN                    NaN
# 19                                      NaN                    NaN
# 20                                      NaN                    NaN
# 21                                      NaN                    NaN
# 22                                      NaN                    NaN
# 23                                      NaN                    NaN
# 24                                      NaN                    NaN
# 25                                      NaN                    NaN
# 26                                      NaN                    NaN
# 27                                      NaN                    NaN
# 28                                      NaN                    NaN
# 29                                      NaN                    NaN
# 30                                      NaN                    NaN
# ...                                     ...                    ...
# 178713                                  NaN                    NaN
# 178714                                  NaN                    NaN
# 178715                                  NaN                    NaN
# 178716                                  NaN                    NaN
# 178717                                  NaN                    NaN
# 178718                                  NaN                    NaN
# 178719                                  NaN                    NaN
# 178720                                  NaN                    NaN
# 178721                                  NaN                    NaN
# 178722                                  NaN                    NaN
# 178723                                  1.0                    NaN
# 178724                                  1.0                    NaN
# 178725                                  1.0                    NaN
# 178726                                  NaN                    NaN
# 178727                                  NaN                    NaN
# 178728                                  NaN                    NaN
# 178729                                  NaN                    NaN
# 178730                                  NaN                    NaN
# 178731                                  NaN                    NaN
# 178732                                  NaN                    NaN
# 178733                                  NaN                    NaN
# 178734                                  NaN                    NaN
# 178735                                  NaN                    NaN
# 178736                                  NaN                    NaN
# 178737                                  NaN                    NaN
# 178738                                  NaN                    NaN
# 178739                                  NaN                    NaN
# 178740                                  NaN                    NaN
# 178741                                  NaN                    NaN
# 178742                                  NaN                    NaN
#
#            Fragmentation Devices Type Fragmentation Devices Weight (Pounds)  \
# Mission ID
# 1                                 NaN                                   NaN
# 2                                 NaN                                   NaN
# 3                                 NaN                                   NaN
# 4                                 NaN                                   NaN
# 5                                 NaN                                   NaN
# 6                                 NaN                                   NaN
# 7                                 NaN                                   NaN
# 8                                 NaN                                   NaN
# 9                                 NaN                                   NaN
# 10                                NaN                                   NaN
# 11                                NaN                                   NaN
# 12                                NaN                                   NaN
# 13                                NaN                                   NaN
# 14                                NaN                                   NaN
# 15                                NaN                                   NaN
# 16                                NaN                                   NaN
# 17                                NaN                                   NaN
# 18                                NaN                                   NaN
# 19                                NaN                                   NaN
# 20                                NaN                                   NaN
# 21                                NaN                                   NaN
# 22                                NaN                                   NaN
# 23                                NaN                                   NaN
# 24                                NaN                                   NaN
# 25                                NaN                                   NaN
# 26                                NaN                                   NaN
# 27                                NaN                                   NaN
# 28                                NaN                                   NaN
# 29                                NaN                                   NaN
# 30                                NaN                                   NaN
# ...                               ...                                   ...
# 178713                            NaN                                   NaN
# 178714                            NaN                                   NaN
# 178715                            NaN                                   NaN
# 178716                            NaN                                   NaN
# 178717                            NaN                                   NaN
# 178718                            NaN                                   NaN
# 178719                            NaN                                   NaN
# 178720                            NaN                                   NaN
# 178721                            NaN                                   NaN
# 178722                            NaN                                   NaN
# 178723                            NaN                                   NaN
# 178724                            NaN                                   NaN
# 178725                            NaN                                   NaN
# 178726                            NaN                                   NaN
# 178727                            NaN                                   NaN
# 178728                            NaN                                   NaN
# 178729                            NaN                                   NaN
# 178730                            NaN                                   NaN
# 178731                            NaN                                   NaN
# 178732                            NaN                                   NaN
# 178733                            NaN                                   NaN
# 178734                            NaN                                   NaN
# 178735                            NaN                                   NaN
# 178736                            NaN                                   NaN
# 178737                            NaN                                   NaN
# 178738                            NaN                                   NaN
# 178739                            NaN                                   NaN
# 178740                            NaN                                   NaN
# 178741                            NaN                                   NaN
# 178742                            NaN                                   NaN
#
#            Fragmentation Devices Weight (Tons) Total Weight (Pounds)  \
# Mission ID
# 1                                          NaN                   NaN
# 2                                          NaN                   NaN
# 3                                          NaN                   NaN
# 4                                          NaN                   NaN
# 5                                          NaN                   NaN
# 6                                          NaN                   NaN
# 7                                          NaN                   NaN
# 8                                          NaN                   NaN
# 9                                          NaN                   NaN
# 10                                         NaN                   NaN
# 11                                         NaN                   NaN
# 12                                         NaN                   NaN
# 13                                         NaN                   NaN
# 14                                         NaN                   NaN
# 15                                         NaN                   NaN
# 16                                         NaN                   NaN
# 17                                         NaN                   NaN
# 18                                         NaN                   NaN
# 19                                         NaN                   NaN
# 20                                         NaN                   NaN
# 21                                         NaN                   NaN
# 22                                         NaN                   NaN
# 23                                         NaN                   NaN
# 24                                         NaN                   NaN
# 25                                         NaN                   NaN
# 26                                         NaN                   NaN
# 27                                         NaN                   NaN
# 28                                         NaN                   NaN
# 29                                         NaN                   NaN
# 30                                         NaN                   NaN
# ...                                        ...                   ...
# 178713                                     NaN                   NaN
# 178714                                     NaN                   NaN
# 178715                                     NaN                   NaN
# 178716                                     NaN                   NaN
# 178717                                     NaN                   NaN
# 178718                                     NaN                   NaN
# 178719                                     NaN                   NaN
# 178720                                     NaN                   NaN
# 178721                                     NaN                   NaN
# 178722                                     NaN                   NaN
# 178723                                     NaN                   NaN
# 178724                                     NaN                   NaN
# 178725                                     NaN                   NaN
# 178726                                     NaN                   NaN
# 178727                                     NaN                   NaN
# 178728                                     NaN                   NaN
# 178729                                     NaN                   NaN
# 178730                                     NaN                   NaN
# 178731                                     NaN                   NaN
# 178732                                     NaN                   NaN
# 178733                                     NaN                   NaN
# 178734                                     NaN                   NaN
# 178735                                     NaN                   NaN
# 178736                                     NaN                   NaN
# 178737                                     NaN                   NaN
# 178738                                     NaN                   NaN
# 178739                                     NaN                   NaN
# 178740                                     NaN                   NaN
# 178741                                     NaN                8000.0
# 178742                                     NaN                   NaN
#
#            Total Weight (Tons) Time Over Target  Bomb Damage Assessment  \
# Mission ID
# 1                         10.0              NaN                     NaN
# 2                         20.0              NaN                     NaN
# 3                          9.0              NaN                     NaN
# 4                          7.5              NaN                     NaN
# 5                          8.0              NaN                     NaN
# 6                          4.0              NaN                     NaN
# 7                          1.0              NaN                     NaN
# 8                          2.0              NaN                     NaN
# 9                          0.0              NaN                     NaN
# 10                         0.0              NaN                     NaN
# 11                         NaN              NaN                     NaN
# 12                         1.0              NaN                     NaN
# 13                         4.0              NaN                     NaN
# 14                        39.0              NaN                     NaN
# 15                        39.0              NaN                     NaN
# 16                        39.0              NaN                     NaN
# 17                         5.0              NaN                     NaN
# 18                         5.0              NaN                     NaN
# 19                         5.0              NaN                     NaN
# 20                        20.0              NaN                     NaN
# 21                        20.0              NaN                     NaN
# 22                        20.0              NaN                     NaN
# 23                        36.0              NaN                     NaN
# 24                        36.0              NaN                     NaN
# 25                        36.0              NaN                     NaN
# 26                         NaN              NaN                     NaN
# 27                         NaN              NaN                     NaN
# 28                         NaN              NaN                     NaN
# 29                        32.0              NaN                     NaN
# 30                        32.0              NaN                     NaN
# ...                        ...              ...                     ...
# 178713                     3.0              NaN                     NaN
# 178714                     3.0              NaN                     NaN
# 178715                     3.0              NaN                     NaN
# 178716                     3.0              NaN                     NaN
# 178717                     3.0              NaN                     NaN
# 178718                     3.0              NaN                     NaN
# 178719                     6.0              NaN                     NaN
# 178720                     3.0              NaN                     NaN
# 178721                     4.0              NaN                     NaN
# 178722                     2.0              NaN                     NaN
# 178723                     3.0              NaN                     NaN
# 178724                     3.0              NaN                     NaN
# 178725                     3.0              NaN                     NaN
# 178726                     2.0              NaN                     NaN
# 178727                     2.0              NaN                     NaN
# 178728                     2.0              NaN                     NaN
# 178729                     2.0              NaN                     NaN
# 178730                     2.0              NaN                     NaN
# 178731                     2.0              NaN                     NaN
# 178732                     1.0              NaN                     NaN
# 178733                     1.0              NaN                     NaN
# 178734                     1.0              NaN                     NaN
# 178735                     1.0              NaN                     NaN
# 178736                     1.0              NaN                     NaN
# 178737                     1.0              NaN                     NaN
# 178738                     1.0              NaN                     NaN
# 178739                     1.0              NaN                     NaN
# 178740                     1.0              NaN                     NaN
# 178741                     4.0              NaN                     NaN
# 178742                     1.0              NaN                     NaN
#
#             Source ID
# Mission ID
# 1                 NaN
# 2              9366.0
# 3                 NaN
# 4                 NaN
# 5             22585.0
# 6              9349.0
# 7             11287.0
# 8             11326.0
# 9                 NaN
# 10                NaN
# 11            37192.0
# 12           292817.0
# 13           292818.0
# 14            95435.0
# 15           197541.0
# 16           197560.0
# 17            95429.0
# 18           197535.0
# 19           197555.0
# 20            95431.0
# 21           197537.0
# 22           197557.0
# 23            95434.0
# 24           197540.0
# 25           197559.0
# 26            95430.0
# 27           197536.0
# 28           197556.0
# 29           197526.0
# 30           197528.0
# ...               ...
# 178713        30088.0
# 178714        30090.0
# 178715        38056.0
# 178716        38057.0
# 178717        31184.0
# 178718        31185.0
# 178719        14178.0
# 178720        55524.0
# 178721        30381.0
# 178722        40462.0
# 178723        33737.0
# 178724        35546.0
# 178725        31159.0
# 178726        36501.0
# 178727        30089.0
# 178728        36646.0
# 178729        37358.0
# 178730        29258.0
# 178731        35868.0
# 178732        30028.0
# 178733        30029.0
# 178734        35023.0
# 178735        35018.0
# 178736        35019.0
# 178737        35021.0
# 178738        35815.0
# 178739        35020.0
# 178740        35022.0
# 178741            NaN
# 178742        33784.0
#
# [178281 rows x 45 columns]

# %%
df_raw.shape
# Out:
# (178281, 45)

# %%
df_raw.describe()
# Out:
#        Takeoff Longitude  Target Latitude  Target Longitude  \
# count        2980.000000    169565.000000     169543.000000
# mean          220.618627        38.067793         43.340213
# std           454.046956        18.711405         59.681160
# min          -177.328611       -37.416667       -179.451285
# 25%            14.400000        26.250000          7.620000
# 50%            29.851389        47.500000         11.330000
# 75%            96.133222        50.930000         97.400000
# max          1355.000000      1108.000000       1000.650000
#
#        Altitude (Hundreds of Feet)  Airborne Aircraft  Attacking Aircraft  \
# count                120826.000000       82242.000000       125108.000000
# mean                    139.026812          12.329771           10.218899
# std                     186.818278          12.514833           11.246399
# min                       0.000000           0.000000            0.000000
# 25%                      70.000000           2.000000            2.000000
# 50%                     122.000000          11.000000            7.000000
# 75%                     223.000000          17.000000           12.000000
# max                   40000.000000         332.000000          332.000000
#
#        Bombing Aircraft  Aircraft Returned  Aircraft Failed  Aircraft Damaged  \
# count      81612.000000         133.000000       247.000000         38.000000
# mean          12.347486           2.157895         4.275304          2.052632
# std           12.573549           1.369816         5.924758          1.675699
# min            0.000000           1.000000         1.000000          0.000000
# 25%            2.000000           1.000000         1.000000          1.000000
# 50%           11.000000           2.000000         2.000000          1.500000
# 75%           18.000000           3.000000         4.000000          2.750000
# max          332.000000           7.000000        48.000000          9.000000
#
#            ...        High Explosives Weight (Tons)  Incendiary Devices  \
# count      ...                        146201.000000         3283.000000
# mean       ...                            23.911995          132.001965
# std        ...                            90.092020          498.596761
# min        ...                             0.000000            0.000000
# 25%        ...                             2.000000            7.000000
# 50%        ...                             9.000000           14.000000
# 75%        ...                            30.000000           32.000000
# max        ...                         20000.000000         4875.000000
#
#        Incendiary Devices Weight (Pounds)  Incendiary Devices Weight (Tons)  \
# count                          356.000000                      25732.000000
# mean                         19962.732022                         21.527213
# std                          45331.714255                         66.692639
# min                              0.000000                          0.000000
# 25%                            218.750000                          1.000000
# 50%                           2640.000000                          6.000000
# 75%                          12500.000000                         18.000000
# max                         420000.000000                        999.000000
#
#        Fragmentation Devices  Fragmentation Devices Weight (Pounds)  \
# count            5768.000000                             194.000000
# mean              102.684560                            2065.630928
# std               158.941650                            2424.138566
# min                 0.000000                               0.000000
# 25%                10.000000                             598.400000
# 50%                38.461538                            1500.000000
# 75%               133.333333                            2400.000000
# max              3000.000000                           20640.000000
#
#        Fragmentation Devices Weight (Tons)  Total Weight (Pounds)  \
# count                         16902.000000           2.119000e+03
# mean                             12.017136           1.237718e+04
# std                              27.221410           2.064155e+05
# min                               0.000000           0.000000e+00
# 25%                               1.000000           2.100000e+03
# 50%                               3.000000           5.200000e+03
# 75%                              12.000000           1.080000e+04
# max                             900.000000           9.500000e+06
#
#        Total Weight (Tons)      Source ID
# count        166508.000000  174236.000000
# mean             25.760326  152670.902322
# std              90.643876  105544.795936
# min               0.000000       1.000000
# 25%               2.000000   53476.500000
# 50%               9.290000  167604.500000
# 75%              31.000000  211284.250000
# max           20000.000000  699625.000000
#
# [8 rows x 22 columns]

# %%
df_raw.columns
# Out:
# Index(['Mission Date', 'Theater of Operations', 'Country', 'Air Force',
#        'Unit ID', 'Aircraft Series', 'Callsign', 'Mission Type',
#        'Takeoff Base', 'Takeoff Location', 'Takeoff Latitude',
#        'Takeoff Longitude', 'Target ID', 'Target Country', 'Target City',
#        'Target Type', 'Target Industry', 'Target Priority', 'Target Latitude',
#        'Target Longitude', 'Altitude (Hundreds of Feet)', 'Airborne Aircraft',
#        'Attacking Aircraft', 'Bombing Aircraft', 'Aircraft Returned',
#        'Aircraft Failed', 'Aircraft Damaged', 'Aircraft Lost',
#        'High Explosives', 'High Explosives Type',
#        'High Explosives Weight (Pounds)', 'High Explosives Weight (Tons)',
#        'Incendiary Devices', 'Incendiary Devices Type',
#        'Incendiary Devices Weight (Pounds)',
#        'Incendiary Devices Weight (Tons)', 'Fragmentation Devices',
#        'Fragmentation Devices Type', 'Fragmentation Devices Weight (Pounds)',
#        'Fragmentation Devices Weight (Tons)', 'Total Weight (Pounds)',
#        'Total Weight (Tons)', 'Time Over Target', 'Bomb Damage Assessment',
#        'Source ID'],
#       dtype='object')

# %% [markdown]
# ## Cleaning the data set

# %%
df_clean = df_raw.copy()

# %%
df_clean.dtypes
# Out:
# Mission Date                              object
# Theater of Operations                     object
# Country                                   object
# Air Force                                 object
# Unit ID                                   object
# Aircraft Series                           object
# Callsign                                  object
# Mission Type                              object
# Takeoff Base                              object
# Takeoff Location                          object
# Takeoff Latitude                          object
# Takeoff Longitude                        float64
# Target ID                                 object
# Target Country                            object
# Target City                               object
# Target Type                               object
# Target Industry                           object
# Target Priority                           object
# Target Latitude                          float64
# Target Longitude                         float64
# Altitude (Hundreds of Feet)              float64
# Airborne Aircraft                        float64
# Attacking Aircraft                       float64
# Bombing Aircraft                         float64
# Aircraft Returned                        float64
# Aircraft Failed                          float64
# Aircraft Damaged                         float64
# Aircraft Lost                            float64
# High Explosives                          float64
# High Explosives Type                      object
# High Explosives Weight (Pounds)           object
# High Explosives Weight (Tons)            float64
# Incendiary Devices                       float64
# Incendiary Devices Type                   object
# Incendiary Devices Weight (Pounds)       float64
# Incendiary Devices Weight (Tons)         float64
# Fragmentation Devices                    float64
# Fragmentation Devices Type                object
# Fragmentation Devices Weight (Pounds)    float64
# Fragmentation Devices Weight (Tons)      float64
# Total Weight (Pounds)                    float64
# Total Weight (Tons)                      float64
# Time Over Target                          object
# Bomb Damage Assessment                    object
# Source ID                                float64
# dtype: object

# %% [markdown]
# **Convert `Mission Date` variable to `datetime` object**

# %%
df_clean.loc[0:15, "Mission Date"]
# Out:
# Mission ID
# 1     8/15/1943
# 2     8/15/1943
# 3     8/15/1943
# 4     8/15/1943
# 5     8/15/1943
# 6     8/15/1943
# 7     8/15/1943
# 8     8/15/1943
# 9     8/15/1943
# 10    8/15/1943
# 11    8/15/1943
# 12    8/15/1943
# 13    8/15/1943
# 14    8/15/1943
# 15    8/15/1943
# Name: Mission Date, dtype: object

# %% [markdown]
# `month/day/year` format

# %%
pd.to_datetime(df_clean["Mission Date"], infer_datetime_format=True).head()
# Out:
# Mission ID
# 1   1943-08-15
# 2   1943-08-15
# 3   1943-08-15
# 4   1943-08-15
# 5   1943-08-15
# Name: Mission Date, dtype: datetime64[ns]

# %%
df_clean["Mission Date"] = pd.to_datetime(df_clean["Mission Date"], infer_datetime_format=True)

# %% [markdown]
# **Check for `NaN` **

# %%
df_clean.shape[0]
# Out:
# 178281

# %%
df_clean.isnull().sum()
# Out:
# Mission Date                                  0
# Theater of Operations                      3158
# Country                                   51787
# Air Force                                 51837
# Unit ID                                  127368
# Aircraft Series                             116
# Callsign                                 178260
# Mission Type                             131095
# Takeoff Base                             174898
# Takeoff Location                         174943
# Takeoff Latitude                         175300
# Takeoff Longitude                        175301
# Target ID                                 50875
# Target Country                              599
# Target City                                2263
# Target Type                               31911
# Target Industry                           51802
# Target Priority                           43561
# Target Latitude                            8716
# Target Longitude                           8738
# Altitude (Hundreds of Feet)               57455
# Airborne Aircraft                         96039
# Attacking Aircraft                        53173
# Bombing Aircraft                          96669
# Aircraft Returned                        178148
# Aircraft Failed                          178034
# Aircraft Damaged                         178243
# Aircraft Lost                            178123
# High Explosives                          143544
# High Explosives Type                     136336
# High Explosives Weight (Pounds)          176260
# High Explosives Weight (Tons)             32080
# Incendiary Devices                       174998
# Incendiary Devices Type                  172762
# Incendiary Devices Weight (Pounds)       177925
# Incendiary Devices Weight (Tons)         152549
# Fragmentation Devices                    172513
# Fragmentation Devices Type               172516
# Fragmentation Devices Weight (Pounds)    178087
# Fragmentation Devices Weight (Tons)      161379
# Total Weight (Pounds)                    176162
# Total Weight (Tons)                       11773
# Time Over Target                         177592
# Bomb Damage Assessment                   178177
# Source ID                                  4045
# dtype: int64

# %%
df_clean.notnull().sum()
# Out:
# Mission Date                             178281
# Theater of Operations                    175123
# Country                                  126494
# Air Force                                126444
# Unit ID                                   50913
# Aircraft Series                          178165
# Callsign                                     21
# Mission Type                              47186
# Takeoff Base                               3383
# Takeoff Location                           3338
# Takeoff Latitude                           2981
# Takeoff Longitude                          2980
# Target ID                                127406
# Target Country                           177682
# Target City                              176018
# Target Type                              146370
# Target Industry                          126479
# Target Priority                          134720
# Target Latitude                          169565
# Target Longitude                         169543
# Altitude (Hundreds of Feet)              120826
# Airborne Aircraft                         82242
# Attacking Aircraft                       125108
# Bombing Aircraft                          81612
# Aircraft Returned                           133
# Aircraft Failed                             247
# Aircraft Damaged                             38
# Aircraft Lost                               158
# High Explosives                           34737
# High Explosives Type                      41945
# High Explosives Weight (Pounds)            2021
# High Explosives Weight (Tons)            146201
# Incendiary Devices                         3283
# Incendiary Devices Type                    5519
# Incendiary Devices Weight (Pounds)          356
# Incendiary Devices Weight (Tons)          25732
# Fragmentation Devices                      5768
# Fragmentation Devices Type                 5765
# Fragmentation Devices Weight (Pounds)       194
# Fragmentation Devices Weight (Tons)       16902
# Total Weight (Pounds)                      2119
# Total Weight (Tons)                      166508
# Time Over Target                            689
# Bomb Damage Assessment                      104
# Source ID                                174236
# dtype: int64

# %%
df_clean.notnull().sum()/df_clean.shape[0]
# Out:
# Mission Date                             1.000000
# Theater of Operations                    0.982286
# Country                                  0.709520
# Air Force                                0.709240
# Unit ID                                  0.285577
# Aircraft Series                          0.999349
# Callsign                                 0.000118
# Mission Type                             0.264672
# Takeoff Base                             0.018976
# Takeoff Location                         0.018723
# Takeoff Latitude                         0.016721
# Takeoff Longitude                        0.016715
# Target ID                                0.714636
# Target Country                           0.996640
# Target City                              0.987307
# Target Type                              0.821007
# Target Industry                          0.709436
# Target Priority                          0.755661
# Target Latitude                          0.951111
# Target Longitude                         0.950987
# Altitude (Hundreds of Feet)              0.677728
# Airborne Aircraft                        0.461305
# Attacking Aircraft                       0.701746
# Bombing Aircraft                         0.457772
# Aircraft Returned                        0.000746
# Aircraft Failed                          0.001385
# Aircraft Damaged                         0.000213
# Aircraft Lost                            0.000886
# High Explosives                          0.194844
# High Explosives Type                     0.235275
# High Explosives Weight (Pounds)          0.011336
# High Explosives Weight (Tons)            0.820059
# Incendiary Devices                       0.018415
# Incendiary Devices Type                  0.030957
# Incendiary Devices Weight (Pounds)       0.001997
# Incendiary Devices Weight (Tons)         0.144334
# Fragmentation Devices                    0.032353
# Fragmentation Devices Type               0.032337
# Fragmentation Devices Weight (Pounds)    0.001088
# Fragmentation Devices Weight (Tons)      0.094805
# Total Weight (Pounds)                    0.011886
# Total Weight (Tons)                      0.933964
# Time Over Target                         0.003865
# Bomb Damage Assessment                   0.000583
# Source ID                                0.977311
# dtype: float64

# %%
threshold = 0.5 # proportion
cols2keep = df_clean.notnull().sum()/df_clean.shape[0] > threshold 
cols2keep
# Out:
# Mission Date                              True
# Theater of Operations                     True
# Country                                   True
# Air Force                                 True
# Unit ID                                  False
# Aircraft Series                           True
# Callsign                                 False
# Mission Type                             False
# Takeoff Base                             False
# Takeoff Location                         False
# Takeoff Latitude                         False
# Takeoff Longitude                        False
# Target ID                                 True
# Target Country                            True
# Target City                               True
# Target Type                               True
# Target Industry                           True
# Target Priority                           True
# Target Latitude                           True
# Target Longitude                          True
# Altitude (Hundreds of Feet)               True
# Airborne Aircraft                        False
# Attacking Aircraft                        True
# Bombing Aircraft                         False
# Aircraft Returned                        False
# Aircraft Failed                          False
# Aircraft Damaged                         False
# Aircraft Lost                            False
# High Explosives                          False
# High Explosives Type                     False
# High Explosives Weight (Pounds)          False
# High Explosives Weight (Tons)             True
# Incendiary Devices                       False
# Incendiary Devices Type                  False
# Incendiary Devices Weight (Pounds)       False
# Incendiary Devices Weight (Tons)         False
# Fragmentation Devices                    False
# Fragmentation Devices Type               False
# Fragmentation Devices Weight (Pounds)    False
# Fragmentation Devices Weight (Tons)      False
# Total Weight (Pounds)                    False
# Total Weight (Tons)                       True
# Time Over Target                         False
# Bomb Damage Assessment                   False
# Source ID                                 True
# dtype: bool

# %%
cols2keep = df_clean.columns[cols2keep.values]
cols2keep
# Out:
# Index(['Mission Date', 'Theater of Operations', 'Country', 'Air Force',
#        'Aircraft Series', 'Target ID', 'Target Country', 'Target City',
#        'Target Type', 'Target Industry', 'Target Priority', 'Target Latitude',
#        'Target Longitude', 'Altitude (Hundreds of Feet)', 'Attacking Aircraft',
#        'High Explosives Weight (Tons)', 'Total Weight (Tons)', 'Source ID'],
#       dtype='object')

# %%
df_clean  = df_clean[cols2keep]
df_clean.shape
# Out:
# (178281, 18)

# %%
df_clean.sample(10)
# Out:
#            Mission Date Theater of Operations        Country Air Force  \
# Mission ID
# 86746        1945-04-15                   ETO            NaN       NaN
# 54714        1944-09-29                   CBI            USA     10 AF
# 74038        1945-04-10                   ETO            USA      8 AF
# 70460        1944-04-07                   MTO            USA     12 AF
# 107390       1944-11-25                   ETO            NaN       NaN
# 146246       1944-06-21                   ETO            USA      8 AF
# 89864        1944-05-01                   CBI  GREAT BRITAIN       RAF
# 28362        1943-12-22                   ETO            USA      9 AF
# 104337       1941-09-13                   ETO  GREAT BRITAIN       RAF
# 52325        1944-09-27                   ETO  GREAT BRITAIN       RAF
#
#            Aircraft Series Target ID Target Country Target City  \
# Mission ID
# 86746                  B24     37276         FRANCE       ROYAN
# 54714                  B25       NaN          BURMA     NAMHKAI
# 74038                  B26     37329        GERMANY  RUDOLSTADT
# 70460                  B25     32353          ITALY        ORTE
# 107390                 B17     27630        GERMANY   MERSEBURG
# 146246                GB17      2829        GERMANY     BASDORF
# 89864                  LIB       NaN          BURMA    MANDALAY
# 28362                  B17     29574        GERMANY     MUNSTER
# 104337                WELL      5882         FRANCE       BREST
# 52325                  HVY     11602        GERMANY    DUISBURG
#
#                     Target Type  \
# Mission ID
# 86746           TACTICAL TARGET
# 54714                    BRIDGE
# 74038                 ORD DEPOT
# 70460               ROAD BRIDGE
# 107390      LEUNA SYN OIL PLANT
# 146246        B M W A C ENGINES
# 89864                       NaN
# 28362                 CITY AREA
# 104337      NAVAL INSTALLATIONS
# 52325                 CITY AREA
#
#                                               Target Industry Target Priority  \
# Mission ID
# 86746       TACTICAL TARGETS: (UNIDENTIFIED OR NOT LISTED ...               1
# 54714                                                     NaN               1
# 74038                             SUPPLY DUMPS AND WAREHOUSES             NaN
# 70460                                                 BRIDGES               1
# 107390                               SYNTHETIC OIL REFINERIES               2
# 146246                                          ENGINE PLANTS               1
# 89864                                                     NaN             NaN
# 28362                            CITIES TOWNS AND URBAN AREAS               1
# 104337                                    NAVAL INSTALLATIONS             NaN
# 52325                            CITIES TOWNS AND URBAN AREAS             NaN
#
#             Target Latitude  Target Longitude  Altitude (Hundreds of Feet)  \
# Mission ID
# 86746             45.630000         -1.030000                        150.0
# 54714             22.350000         97.200000                          NaN
# 74038             50.720000         15.350000                        100.0
# 70460             42.470000         12.400000                        105.0
# 107390            51.350000         12.000000                        261.0
# 146246            52.720000         13.450000                          NaN
# 89864             21.983333         96.083333                          NaN
# 28362             50.130000          8.460000                          NaN
# 104337            48.400000         -4.500000                        150.0
# 52325             51.430000          6.750000                          NaN
#
#             Attacking Aircraft  High Explosives Weight (Tons)  \
# Mission ID
# 86746                     10.0                            NaN
# 54714                      NaN                            6.0
# 74038                      NaN                            NaN
# 70460                     24.0                           48.0
# 107390                    12.0                           29.0
# 146246                     2.0                            5.0
# 89864                      4.0                           20.0
# 28362                      NaN                           49.0
# 104337                     NaN                           55.0
# 52325                     49.0                          188.0
#
#             Total Weight (Tons)  Source ID
# Mission ID
# 86746                      20.0   122882.0
# 54714                       6.0    35471.0
# 74038                      24.0   221883.0
# 70460                      48.0    99729.0
# 107390                     29.0   113400.0
# 146246                      5.0   167092.0
# 89864                       6.0        NaN
# 28362                      73.0   161590.0
# 104337                     55.0   285525.0
# 52325                     188.0   296587.0

# %% [markdown]
# ***
# ## Feature engeneering

# %%
df_eng  = df_clean.copy()

# %% [markdown]
# **Derive three columns, for `year`, `month` and for the sake of completeness `day`**

# %%
df_eng.head()
# Out:
#            Mission Date Theater of Operations Country Air Force  \
# Mission ID
# 1            1943-08-15                   MTO     USA     12 AF
# 2            1943-08-15                   PTO     USA      5 AF
# 3            1943-08-15                   MTO     USA     12 AF
# 4            1943-08-15                   MTO     USA     12 AF
# 5            1943-08-15                   PTO     USA      5 AF
#
#            Aircraft Series Target ID Target Country  Target City Target Type  \
# Mission ID
# 1                      A36     40675          ITALY    SPADAFORA         NaN
# 2                      B24       NaN     NEW GUINEA     KOMIATUM       RIDGE
# 3                      A36      9630          ITALY      COSENZA         NaN
# 4                      A36     16140          ITALY  GIOJA TAURO         NaN
# 5                      B24       NaN        SUMATRA         KILA     VILLAGE
#
#            Target Industry Target Priority  Target Latitude  Target Longitude  \
# Mission ID
# 1                      NaN             NaN        38.220000         15.370000
# 2                      NaN               1        -7.166667        147.000000
# 3                      NaN             NaN        39.270000         16.250000
# 4                      NaN             NaN        38.430000         15.900000
# 5                      NaN               1        -1.116667        103.883333
#
#             Altitude (Hundreds of Feet)  Attacking Aircraft  \
# Mission ID
# 1                                   NaN                 NaN
# 2                                  44.0                 6.0
# 3                                   NaN                 NaN
# 4                                   NaN                 NaN
# 5                                  60.0                 6.0
#
#             High Explosives Weight (Tons)  Total Weight (Tons)  Source ID
# Mission ID
# 1                                    10.0                 10.0        NaN
# 2                                    20.0                 20.0     9366.0
# 3                                     9.0                  9.0        NaN
# 4                                     7.5                  7.5        NaN
# 5                                     8.0                  8.0    22585.0

# %%
df_eng["Mission Date"].dt.year.tail(10)
# Out:
# Mission ID
# 178733    1945
# 178734    1945
# 178735    1945
# 178736    1945
# 178737    1945
# 178738    1945
# 178739    1945
# 178740    1945
# 178741    1945
# 178742    1945
# Name: Mission Date, dtype: int64

# %%
df_eng["year"] = df_eng["Mission Date"].dt.year
df_eng["month"] = df_eng["Mission Date"].dt.month
df_eng["day"] = df_eng["Mission Date"].dt.day

# %% [markdown]
# **Change `Altitude (Hundreds of Feet)` from feet to meters**

# %% [markdown]
# $$1\;\text{foot} =  0.3048\; \text{meter}$$

# %% [markdown]
# `Series.apply()` method

# %%
#df_eng["Altitude (Hundreds of Feet)"]

# %%
df_eng["Altitude (meters)"] = df_eng["Altitude (Hundreds of Feet)"].apply(lambda x: x*100*0.3048)
df_eng["Altitude (meters)"].sample(10)
# Out:
# Mission ID
# 104538    7620.00
# 91561         NaN
# 120135    2743.20
# 131004    2743.20
# 79537     5059.68
# 79986     6096.00
# 24588     7498.08
# 171896    2743.20
# 169928    6858.00
# 138494        NaN
# Name: Altitude (meters), dtype: float64

# %%
df_eng["Altitude (meters)"].plot.hist()

# %%
df_eng["Altitude (meters)"].max()
# Out:
# 1219200.0

# %%
(df_eng["Altitude (meters)"] > 16000).sum()
# Out:
# 24

# %%
df_eng["Altitude (meters)"].loc[df_eng["Altitude (meters)"] > 16000] = np.nan
# Out:
# /data/3rd_party/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_eng["Altitude (meters)"].plot.hist()
plt.title("Histogramm of altitude in meters");

# %% [markdown]
# ***
# ## Exploratory data anylysis

# %%
df = df_eng.copy()
df.shape
# Out:
# (178281, 22)

# %%
df.columns
# Out:
# Index(['Mission Date', 'Theater of Operations', 'Country', 'Air Force',
#        'Aircraft Series', 'Target ID', 'Target Country', 'Target City',
#        'Target Type', 'Target Industry', 'Target Priority', 'Target Latitude',
#        'Target Longitude', 'Altitude (Hundreds of Feet)', 'Attacking Aircraft',
#        'High Explosives Weight (Tons)', 'Total Weight (Tons)', 'Source ID',
#        'year', 'month', 'day', 'Altitude (meters)'],
#       dtype='object')

# %%
df.head()
# Out:
#            Mission Date Theater of Operations Country Air Force  \
# Mission ID
# 1            1943-08-15                   MTO     USA     12 AF
# 2            1943-08-15                   PTO     USA      5 AF
# 3            1943-08-15                   MTO     USA     12 AF
# 4            1943-08-15                   MTO     USA     12 AF
# 5            1943-08-15                   PTO     USA      5 AF
#
#            Aircraft Series Target ID Target Country  Target City Target Type  \
# Mission ID
# 1                      A36     40675          ITALY    SPADAFORA         NaN
# 2                      B24       NaN     NEW GUINEA     KOMIATUM       RIDGE
# 3                      A36      9630          ITALY      COSENZA         NaN
# 4                      A36     16140          ITALY  GIOJA TAURO         NaN
# 5                      B24       NaN        SUMATRA         KILA     VILLAGE
#
#            Target Industry        ...         Target Longitude  \
# Mission ID                        ...
# 1                      NaN        ...                15.370000
# 2                      NaN        ...               147.000000
# 3                      NaN        ...                16.250000
# 4                      NaN        ...                15.900000
# 5                      NaN        ...               103.883333
#
#             Altitude (Hundreds of Feet)  Attacking Aircraft  \
# Mission ID
# 1                                   NaN                 NaN
# 2                                  44.0                 6.0
# 3                                   NaN                 NaN
# 4                                   NaN                 NaN
# 5                                  60.0                 6.0
#
#             High Explosives Weight (Tons)  Total Weight (Tons)  Source ID  \
# Mission ID
# 1                                    10.0                 10.0        NaN
# 2                                    20.0                 20.0     9366.0
# 3                                     9.0                  9.0        NaN
# 4                                     7.5                  7.5        NaN
# 5                                     8.0                  8.0    22585.0
#
#             year  month  day  Altitude (meters)
# Mission ID
# 1           1943      8   15                NaN
# 2           1943      8   15            1341.12
# 3           1943      8   15                NaN
# 4           1943      8   15                NaN
# 5           1943      8   15            1828.80
#
# [5 rows x 22 columns]

# %%
df.reset_index().groupby("Mission Date").count()["Mission ID"].plot()

# %%
df.Country.unique()
# Out:
# array(['USA', 'GREAT BRITAIN', nan, 'NEW ZEALAND', 'SOUTH AFRICA',
#        'AUSTRALIA'], dtype=object)

# %%
df.reset_index().groupby("Country").count()["Mission ID"].plot.bar()

# %%
df.reset_index().groupby(["year",  "Country"]).count()["Mission ID"].unstack().plot.bar(rot=0)

# %%
df.reset_index().groupby(["month",  "Country"]).count()["Mission ID"].unstack().plot.bar(rot=0)

# %%
df.groupby(["year",  "Country"]).mean()['Altitude (meters)'].unstack().plot.bar()

# %%
df.groupby(["Country"]).agg(["max", "median"])['Altitude (meters)'].plot.bar()

# %%
df['High Explosives Weight (Tons)'].plot.hist(bins=100)

# %%
df.groupby(["Country"]).agg(["mean", "median"])['High Explosives Weight (Tons)'].plot.bar()

# %%
df.groupby(["year",  "Country"]).median()['High Explosives Weight (Tons)'].unstack().plot.bar()

# %%
_ = df.groupby("Target Country")["Target Country"].value_counts()
_[_ > 2000].plot.pie()

# %%
df.reset_index().groupby(["year",  "Target Country"])["Mission ID"].count().sort_values(ascending=False)#.unstack().plot.bar()
# Out:
# year  Target Country
# 1944  GERMANY                       26757
# 1945  GERMANY                       17718
# 1944  FRANCE                        15270
# 1945  ITALY                          8616
# 1944  ITALY                          7884
# 1945  PHILIPPINE ISLANDS             6998
# 1943  ITALY                          6880
# 1941  GERMANY                        6757
# 1944  NEW GUINEA                     5073
#       BURMA                          4293
# 1943  GERMANY                        4131
# 1940  GERMANY                        3852
# 1944  CELEBES ISLANDS                2527
# 1943  FRANCE                         2525
# 1945  JAPAN                          2511
# 1942  GERMANY                        2488
# 1944  AUSTRIA                        2363
#       CHINA                          2246
# 1945  BURMA                          2224
#       AUSTRIA                        1921
# 1943  TUNISIA                        1849
# 1945  FORMOSA AND RYUKYU ISLANDS     1721
# 1944  BISMARK ARCHIPELAGO            1708
# 1945  CHINA                          1562
#       UNKNOWN OR NOT INDICATED       1546
# 1941  FRANCE                         1405
# 1943  BURMA                          1374
# 1940  FRANCE                         1270
# 1943  BISMARK ARCHIPELAGO            1263
# 1945  FRANCE                         1179
#                                     ...
# 1940  AUSTRIA                           2
# 1942  CORAL SEA AREA                    2
# 1943  ANDAMAN ISLANDS                   1
# 1940  ETHIOPIA/ABSINNYA                 1
# 1943  HUNGARY                           1
#       INDIA                             1
# 1944  LIBYA                             1
# 1940  CZECHOSLOVAKIA                    1
# 1943  MARIANAS ISLANDS                  1
#       UNKNOWN                           1
# 1945  THAILAND OR SIAM MINING           1
# 1942  BULGARIA                          1
# 1940  UNKNOWN OR NOT INDICATED          1
# 1941  AUSTRIA                           1
# 1942  DENMARK                           1
#       FORMOSA AND RYUKYU ISLANDS        1
# 1945  FORMOSA                           1
# 1941  UNKNOWN OR NOT INDICATED          1
#       ROMANIA                           1
# 1942  INDIAN OCEAN                      1
# 1945  ALEUTIAN ISLANDS                  1
#       MANCHURIA                         1
# 1942  MALAY STATES                      1
#       NETHERLANDS EAST INDIES           1
# 1944  TURKEY                            1
# 1941  ETHIOPIA/ABSINNYA                 1
# 1942  ROMANIA                           1
#       CELEBES ISLANDS                   1
# 1944  SUMATRA MINING                    1
# 1943  MOROCCO                           1
# Name: Mission ID, dtype: int64

# %%
len(df["Target Type"].unique())
# Out:
# 2936

# %%
len(df["Target Industry"].unique())
# Out:
# 56

# %%
df.reset_index().groupby("Target Industry").count()["Mission ID"].sort_values(ascending=False).plot.bar(figsize=(16,4))

# %%
df['Target Country'].unique()
# Out:
# array(['ITALY', 'NEW GUINEA', 'SUMATRA', 'BURMA', 'GERMANY',
#        'HOLLAND OR NETHERLANDS', 'FRANCE', 'UNKNOWN OR NOT INDICATED',
#        'CORAL SEA AREA', 'SOLOMON ISLANDS', 'BORNEO', 'CHINA',
#        'CAROLINE ISLANDS', 'KURILE ISLANDS', 'CELEBES ISLANDS',
#        'MARIANAS ISLANDS', 'BISMARK ARCHIPELAGO', 'MANCHURIA', 'JAVA',
#        'VOLCANO AND BONIN ISLANDS', 'PHILIPPINE ISLANDS', 'JAPAN',
#        'AUSTRIA', 'BELGIUM', 'ALEUTIAN ISLANDS', nan,
#        'FORMOSA AND RYUKYU ISLANDS', 'NEW IRELAND', 'MARCUS ISLANDS',
#        'GREECE', 'HUNGARY', 'YUGOSLAVIA', 'FRENCH INDO CHINA',
#        'MARSHALL ISLANDS', 'PALAU ISLANDS', 'MALAY STATES', 'ROMANIA',
#        'INDIA', 'SWITZERLAND', 'ALBANIA', 'LUXEMBOURG', 'POLAND',
#        'ALGERIA', 'NORWAY', 'GILBERT ISLANDS', 'CRETE',
#        'MALAY STATES MINING', 'SUMATRA MINING', 'CZECHOSLOVAKIA',
#        'FORMOSA', 'SARDINIA', 'CHINA MINING', 'BULGARIA',
#        'KOREA OR CHOSEN', 'DENMARK', 'GREAT BRITAIN', 'THAILAND OR SIAM',
#        'CORSICA', 'LIBYA', 'ERITREA', 'ETHIOPIA', 'SUDAN', 'WAKE ISLAND',
#        'JAPAN MINING', 'BOUGAINVILLE', 'FRENCH INDO CHINA MINING',
#        'ETHIOPIA/ABSINNYA', 'SOMALIA', 'UNKNOWN', 'SICILY', 'MADAGASCAR',
#        'IRAQ', 'LEBANON', 'SYRIA', 'TUNISIA', 'CYPRUS', 'TURKEY',
#        'NETHERLANDS EAST INDIES', 'INDONESIA', 'BALI', 'ANDAMAN ISLANDS',
#        'INDIAN OCEAN', 'TIMOR', 'EGYPT', 'AUSTRALIA', 'FRENCH WEST AFRICA',
#        '"PAPUA NEW GUINEA, MANUS ISLAND"', 'KOREA OR CHOSEN MINING',
#        'PANTELLARIA', 'MOROCCO', 'THAILAND OR SIAM MINING'], dtype=object)

# %%
df.reset_index().groupby("Target Country").count()["Mission ID"].sort_values(ascending=False).plot.bar(figsize=(16,4))

# %%
df.groupby("Target Country").sum()["High Explosives Weight (Tons)"].sort_values(ascending=False).plot.bar(figsize=(16,4))

# %% [markdown]
# ***
# ### Spatial Data

# %%
import geopandas as gpd
from shapely.geometry import Point
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-58-14fa2ec568b7> in <module>()
# ----> 1 import geopandas as gpd
#       2 from shapely.geometry import Point
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
df.columns

# %%
df[['Target Latitude', 'Target Longitude']].head()

# %%
geometry = [Point(xy) for xy in zip(df['Target Longitude'], df['Target Latitude'])]
gdf = gpd.GeoDataFrame(df, geometry=geometry)
gdf.head()

# %%
gdf.plot()

# %%
_ = gdf.loc[((gdf['Target Longitude'] > 180) | 
             (gdf['Target Longitude'] < -180) | 
             (df['Target Latitude'] > 90 )| 
             (df['Target Latitude'] < -90)), ['Target Longitude', 'Target Latitude']]
print(_.shape)
_.sample(15)

# %%
gdf = gdf.loc[~(
    (gdf['Target Longitude'] > 180) |
    (gdf['Target Longitude'] < -180) |                
    (df['Target Latitude'] > 90)| 
    (df['Target Latitude'] < -90)
               )
             ]
print(gdf.shape)

# %%
gdf[['Target Longitude', 'Target Latitude']].isnull().sum()

# %%
gdf = gdf.loc[gdf[['Target Longitude', 'Target Latitude']].notnull().all(axis = 1)]
print(gdf.shape)

# %%
gdf.plot()

# %%
gdf.crs =  {'init' :'epsg:4326'}

# %% [markdown]
# ### Load “Natural Earth” countries dataset, bundled with GeoPandas
#
# “[Natural Earth](http://www.naturalearthdata.com/) is a public domain map dataset available at 1:10m, 1:50m, and 1:110 million scales. Featuring tightly integrated vector and raster data, with Natural Earth you can make a variety of visually pleasing, well-crafted maps with cartography or GIS software.” A subset comes bundled with GeoPandas and is accessible from the gpd.datasets module. We’ll use it as a helpful global base layer map.

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.head(2)

# %%
world.crs

# %%
world.plot(facecolor='lightgray')

# %%
base=world.plot(facecolor='lightgray')
gdf.plot(ax=base, marker='o', color='red', markersize=10, alpha=0.01)

# %%
gdf["Target Country"].isin(["GERMANY", "FRANCE", "ITALY"]).sum()/gdf.shape[0]

# %% [markdown]
# Area: 73.5°N 27.0°W 33.0°N 45.0°E

# %%
from shapely.geometry import Polygon
poly_europe = gpd.GeoSeries([Polygon([(-27,33), (45,33), (45,73.5), (-27,73.5)])])
bb_europe = gpd.GeoDataFrame({'geometry': poly_europe})
bb_europe.crs = {'init' :'epsg:4326'}

# %%
base=world.plot(facecolor='lightgray')
bb_europe.plot(ax=base,alpha=0.5)

# %%
gdf_europe = gpd.sjoin(gdf, bb_europe, how="inner", op='intersects')
print(gdf_europe.shape)

# %%
gdf_europe.plot()

# %%
europe = gpd.overlay(world, bb_europe, how='intersection')

# %%
base=europe.plot(facecolor='lightgray')
gdf_europe.plot(ax=base, marker='o', color='red', markersize=5, alpha=0.01)

# %% [markdown]
# #### Kernel density plot

# %%
import seaborn as sns

# %%
#fig, ax = plt.subplots(224)
fig = plt.figure(figsize=(16,12))
# set aspect to equal. This is done automatically
# when using *geopandas* plot on it's own, but not when
# working with pyplot directly.
bws = [0.2, 0.4, 0.6, 0.8]
for e in range(4):
    ax = plt.subplot(2,2,e+1)
    ax.set_aspect('equal')
    europe.plot(ax=ax, facecolor='lightgray')
    sns.kdeplot(gdf_europe['Target Longitude'], gdf_europe['Target Latitude'],
                cmap="viridis", shade=True, shade_lowest=False, ax=ax, bw=bws[e])
    ax.set_title("Bandwith: " + str(bws[e]), size=16)
plt.tight_layout()
plt.suptitle("KDE for different bandwith parameters", size=22);

# %%
gdf_europe.Country.unique()

# %%
gdf_europe.Country.replace(np.nan, "unknown", inplace=True)

# %%
fig = plt.figure(figsize=(16,12))
years = [1940, 1941 ,1942, 1943, 1944, 1945]
for e in range(len(years)):
    ax = plt.subplot(3,2,e+1)
    ax.set_aspect('equal')
    europe.plot(ax=ax, facecolor='lightgray')
    _ = gdf_europe.loc[gdf_europe.year == years[e]]
    _.plot(ax=ax, marker='o', cmap='Set1',           
           column='Country', legend=True, 
           markersize=5, alpha=1)
    ax.set_title("Year: " + str(years[e]), size=16)    
plt.tight_layout()
plt.suptitle("Attacks for different years", size=22)
plt.subplots_adjust(top=0.92)
